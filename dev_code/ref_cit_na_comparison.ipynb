# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np

# %%
citizen_fnames = os.listdir('../data/citizen_states_cleaned')
ref_fnames = os.listdir('../data/reference_states_cleaned')
# Out:
# ['tamil_nadu.csv',
#  'delhi.csv',
#  'manipur.csv',
#  'jharkhand.csv',
#  'assam.csv',
#  'rajasthan.csv',
#  'jammu_and_kashmir.csv',
#  'tripura.csv',
#  'karnataka.csv',
#  'puducherry.csv',
#  'arunachal_pradesh.csv',
#  'madhya_pradesh.csv',
#  'odisha.csv',
#  'meghalaya.csv',
#  'gujarat.csv',
#  'andhra_pradesh.csv',
#  'andaman_and_nicobar_islands.csv',
#  'kerala.csv',
#  'haryana.csv',
#  'maharashtra.csv',
#  'bihar.csv']

# %%
# make the id lookup dict for the citizen datapoints
species_codes = pd.read_csv("../data/species codes.csv", encoding='unicode_escape')

species_id_to_name = {}
species_name_to_id = {}

for i, row in species_codes.iterrows():
    species_id_to_name[row["species_id"]] = "{}-{}".format(row["species_primary_common_name"], row["species_scientific_name"])
    species_name_to_id["{}-{}".format(row["species_primary_common_name"], row["species_scientific_name"]).lower().replace(" ", "")] = row["species_id"]
# Out:
# dict_keys(['whitebabool-acacialeucophloea', 'babool-acacianilotica', 'woodapple-aeglemarmelos', 'indianhorsechestnut-aesculusindica', 'treeofheaven-ailanthusexcelsa', 'krishnasiris-albiziaamara', 'siris-albizialebbeck', 'whitesiris-albiziaprocera', "devil'stree-alstoniascholaris", 'axlewood-anogeissuslatifolia', 'greymangrove-avicenniamarina', 'neem-azadirachtaindica', 'purplebauhinia-bauhiniapurpurea', 'jhinjheri-bauhiniaracemosa', 'semla-bauhiniaretusa', 'redsilkcotton-bombaxceiba', 'toddypalm-borassusflabellifer', 'flameoftheforest-buteamonosperma', 'blackdammer-canariumstrictum', 'fish-tailpalm-caryotaurens', 'indianlaburnum-cassiafistula', 'whitesilkcotton-ceibapentandra', 'flosssilktree-ceibaspeciosa', 'yellowsilkcotton-cochlospermumreligiosum', 'mountaincoffee-coffeaarabica', 'robustacoffee-coffearobusta', 'largesebesten-cordiawallichii', "tanner'stree-coriarianepalensis", 'takoli-dalbergialanceolaria', 'indianrosewood-dalbergiasissoo', 'gulmohur-delonixregia', 'elephantapple-dilleniaindica', 'karkat-dilleniapentagyna', 'duabanga-duabangagrandiflora', 'indiancoral-erythrinaindica', 'banyan-ficusbenghalensis', 'countryfig-ficusracemosa', 'peepal-ficusreligiosa', 'garuga-garugapinnata', 'quickstick-gliricidiasepium', 'gamar-gmelinaarborea', 'indianelm-holopteleaintegrifolia', 'jacaranda-jacarandamimosifolia', 'sausagetree-kigeliaafricana', 'roxburghskydia,pulia-kydiacalycina', 'prideofindia-lagerstroemiaspeciosa', 'lantana-lantanacamara', 'chandada-macarangapeltata', 'mahua-madhucalongifolia(var.latifolia)', 'chinaberry-meliaazedarach', 'nagchampa-mesuaferrea', 'champa-micheliachampaca', 'indiancorktree-millingtoniahortensis', 'maulsari-mimusopselengi', 'kaim-mitragynaparviflora', 'silkwormmulberry-morusalba', 'singaporecherry-muntingiacalabura', 'kadamb-neolamarckiacadamba', 'nightfloweringjasmine-nyctanthesarbor-tristis', 'badminton-balltree-parkiabiglandulosa', 'copper-pod-peltophorumpterocarpum', 'khajur-phoenixsylvestris', 'amla-phyllanthusemblica', 'junglejalebi-pithecellobiumdulce', 'masttree-monoonlongifolium', 'pongamtree-pongamiapinnata', 'vilaitikeekar-prosopisjuliflora', 'kanakchampa-pterospermumacerifolium', 'pomegranate-punicagranatum', 'greyoak-quercusleucotrichophora', 'himalayanrhododendron-rhododendronarboreum', 'nilgirirhododendron-rhododendronnilagiricum', 'sandalwood-santalumalbum', 'trueashoka-saracaasoca', 'sal-shorearobusta', 'africantulip-spathodeacampanulata', 'wildalmond-sterculiafoetida', 'ghosttree-sterculiaurens', 'jamun-syzygiumcumini', 'caribbeantrumpettree-tabebuiaaurea', 'tamarind-tamarindusindica', 'teak-tectonagrandis', 'arjun-terminaliaarjuna', 'beheda-terminaliabellirica', 'indianalmond-terminaliacatappa', 'indianlaurel-terminaliatomentosa', 'indianmahogany-toonaciliata', 'falsewhiteteak-trewianudiflora', 'ber-ziziphusmauritiana', 'mango(allvarieties)-mangiferaindica', 'mango:aabehayat-mangiferaindica', 'mango:airi-mangiferaindica', 'mango:allampurbeneshan-mangiferaindica', 'mango:alphonso-mangiferaindica', 'mango:amrapali-mangiferaindica', 'mango:arkapuneet-mangiferaindica', 'mango:badami-mangiferaindica', 'mango:bangalora-mangiferaindica', 'mango:banganpalli-mangiferaindica', 'mango:bathua-mangiferaindica', 'mango:beneshan-mangiferaindica', 'mango:bombai-mangiferaindica', 'mango:bombaygreen(sarauli)-mangiferaindica', 'mango:cherukurasam-mangiferaindica', 'mango:cherukurasam-nan', 'mango:chinnarasam-mangiferaindica', 'mango:chosa-mangiferaindica', 'mango:dussheri-mangiferaindica', 'mango:fazli-mangiferaindica', 'mango:fernandin-mangiferaindica', 'mango:gilas-mangiferaindica', 'mango:gulabkhas-mangiferaindica', 'mango:hardil-aziz-mangiferaindica', 'mango:himayat-mangiferaindica', 'mango:himayuddin-mangiferaindica', 'mango:himsagar-mangiferaindica', 'mango:husnaara-mangiferaindica', 'mango:jamadar-mangiferaindica', 'mango:jehangir-mangiferaindica', 'mango:kaju-mangiferaindica', 'mango:kesar-mangiferaindica', 'mango:khattameetha-mangiferaindica', 'mango:kishenbhog-mangiferaindica', 'man ...

# %%
# Find proportion of datapoints in citizen data which map to NA (missing values) in reference data
cat_attributes = ['Leaves_fresh', 'Leaves_mature', 'Leaves_old', 'Flowers_bud', 'Flowers_open', 'Flowers_male', 'Flowers_Female', 'Fruits_unripe', 'Fruits_ripe', 'Fruits_open']
val_df = pd.DataFrame(columns=['State Name', 'total_obs', 'proportion of -2 <-> NA', 'proportion of -1 <-> NA', 'proportion of 0 <-> NA', 'proportion of 1 <-> NA', 'proportion of 2 <-> NA'])

for fname in ref_fnames:
    print("calculating proportions for {}".format(fname))
    df_cit = pd.read_csv(f"../data/citizen_states_cleaned/{fname}")
    df_ref = pd.read_csv(f"../data/reference_states_cleaned/{fname}")
    n_obs = 10 * len(df_cit)
    
    species_idweek_to_data_dict = {}
    for _, row in df_ref.iterrows():
        data = list(map(lambda attr: row[attr], cat_attributes))
        species_idweek_to_data_dict[(row['week'], row['species_id'])] = data.copy()

    na_counts = {-2: 0, -1: 0, 0: 0, 1: 0, 2: 0}
    
    for _, row_i in df_cit.iterrows():
        week = row_i['Week']
        try:
            species_id = species_name_to_id[row_i['Species_name'].lower().replace(" ", "")]
        except:
            print("Warning: no id for {}".format(row_i['Species_name']))
            continue
        try:
            ref_row = species_idweek_to_data_dict[(row_i['Week'], species_id)]
        except:
            print("Warning: (week, id) pair ({}, {}) not found in reference data".format(row_i['Week'], species_id))
            continue
        for attr in cat_attributes:
            ref_row_attr_val = ref_row[cat_attributes.index(attr)]
            if ref_row_attr_val == -2:
                # print(attr, row_i[attr])
                if row_i[attr] in [-2.0, -1.0, 0, 1.0, 2.0]:
                    na_counts[int(row_i[attr])] += 1
    print(na_counts)
    val_df.loc[len(val_df)] = {'State Name': fname.replace('.csv', ''), 'total_obs': n_obs, 'proportion of -2 <-> NA': na_counts[-2]/n_obs, 'proportion of -1 <-> NA': na_counts[-1]/n_obs, 'proportion of 0 <-> NA': na_counts[0]/n_obs, 'proportion of 1 <-> NA': na_counts[1]/n_obs, 'proportion of 2 <-> NA': na_counts[2]/n_obs}
# Out:
# calculating proportions for tamil_nadu.csv
# Warning: no id for Broken Bones Tree-Oroxylum Indicum
# Warning: no id for Broken Bones Tree-Oroxylum Indicum
# Warning: (week, id) pair (36, 1228) not found in reference data
# Warning: (week, id) pair (30, 1228) not found in reference data
# Warning: (week, id) pair (37, 1228) not found in reference data
# Warning: no id for Tiger's Milk Spruce-Falconeria Insignis
# {-2: 36544, -1: 676, 0: 30611, 1: 23316, 2: 24705}
# calculating proportions for delhi.csv
# {-2: 1007, -1: 18, 0: 841, 1: 185, 2: 180}
# calculating proportions for manipur.csv
# {-2: 411, -1: 0, 0: 323, 1: 137, 2: 307}
# calculating proportions for jharkhand.csv
# {-2: 292, -1: 88, 0: 335, 1: 244, 2: 237}
# calculating proportions for assam.csv
# Warning: no id for Broken Bones Tree-Oroxylum Indicum
# Warning: no id for Broken Bones Tree-Oroxylum Indicum
# {-2: 1328, -1: 57, 0: 1662, 1: 920, 2: 1186}
# calculating proportions for rajasthan.csv
# {-2: 2698, -1: 46, 0: 4115, 1: 1259, 2: 1715}
# calculating proportions for jammu_and_kashmir.csv
# Warning: no id for Chinar-Platanus Orientalis
# Warning: no id for Chinar-Platanus Orientalis
# Warning: no id for Chinar-Platanus Orientalis
# Warning: no id for Chinar-Platanus Orientalis
# Warning: no id for Chinar-Platanus Orientalis
# Warning: no id for Chinar-Platanus Orientalis
# {-2: 36, -1: 0, 0: 52, 1: 29, 2: 25}
# calculating proportions for tripura.csv
# {-2: 95, -1: 0, 0: 53, 1: 45, 2: 61}
# calculating proportions for karnataka.csv
# Warning: no id for Broken Bones Tree-Oroxylum Indicum
# Warning: no id for Broken Bones Tree-Oroxylum Indicum
# Warning: (week, id) pair (43, 1024) not found in reference data
# Warning: (week, id) pair (43, 1024) not found in reference data
# Warning: (week, id) pair (43, 1024) not found in reference data
# Warning: (week, id) pair (8, 1024) not found in reference data
# Warning: (week, id) pair (43, 1024) not found in reference data
# {-2: 22216, -1: 686, 0: 23662, 1: 9887, 2: 15682}
# calculating proportions for puducherry.csv
# {-2: 5015, -1: 47, 0: 4763, 1: 5623, 2: 3449}
# calculating proportions for arunachal_pradesh.csv
# {-2: 214, -1: 0, 0: 195, 1: 61, 2: 88}
# calculating proportions for madhya_pradesh.csv
# Warning: no id for Broken Bones Tree-Oroxylum Indicum
# {-2: 14874, -1: 1242, 0: 29598, 1: 11615, 2: 10082}
# calculating proportions for odisha.csv
# {-2: 3566, -1: 36, 0: 7515, 1: 2303, 2: 4213}
# calculating proportions for meghalaya.csv
# {-2: 7773, -1: 102, 0: 18567, 1: 5159, 2: 7926}
# calculating proportions for gujarat.csv
# {-2: 6304, -1: 369, 0: 9663, 1: 4224, 2: 3996}
# calculating proportions for andhra_pradesh.csv
# {-2: 3480, -1: 94, 0: 6951, 1: 5714, 2: 5975}
# calculating proportions for andaman_and_nicobar_islands.csv
# Warning: no id for Broken Bones Tree-Oroxylum Indicum
# Warning: no id for Broken Bones Tree-Oroxylum Indicum
 1024) not found in reference data
# Warning: (week, id) pair (9, 1024) not found in reference data
# Warning: (week, id) pair (32, 1024) not found in reference data
# Warning: (week, id) pair (45, 1024) not found in reference data
# Warning: (week, id) pair (23, 1024) not found in reference data
# Warning: (week, id) pair (30, 1024) not found in reference data
# Warning: (week, id) pair (43, 1024) not found in reference data
# Warning: (week, id) pair (24, 1024) not found in reference data
# Warning: (week, id) pair (33, 1024) not found in reference data
# Warning: (week, id) pair (40, 1024) not found in reference data
# Warning: (week, id) pair (27, 1024) not found in reference data
# Warning: (week, id) pair (28, 1024) not found in reference data
# Warning: (week, id) pair (29, 1024) not found in reference data
# Warning: (week, id) pair (30, 1024) not found in reference data
# Warning: (week, id) pair (31, 1024) not found in reference data
# Warning: (week, id) pair (46, 1024) not found in reference data
# Warning: (week, id) pair (42, 1024) not found in reference data
# Warning: (week, id) pair (9, 1024) not found in reference data
# Warning: (week, id) pair (26, 1024) not found in reference data
# Warning: (week, id) pair (18, 1024) not found in reference data
# Warning: (week, id) pair (43, 1024) not found in reference data
# Warning: (week, id) pair (1, 1024) not found in reference data
# Warning: (week, id) pair (37, 1024) not found in reference data
# Warning: (week, id) pair (14, 1024) not found in reference data
# Warning: (week, id) pair (23, 1024) not found in reference data
# Warning: (week, id) pair (16, 1024) not found in reference data
# Warning: (week, id) pair (32, 1024) not found in reference data
# Warning: (week, id) pair (9, 1024) not found in reference data
# Warning: (week, id) pair (19, 1024) not found in reference data
# Warning: (week, id) pair (26, 1024) not found in reference data
# Warning: (week, id) pair (18, 1024) not found in reference data
# Warning: (week, id) pair (4, 1024) not found in reference data
# Warning: (week, id) pair (43, 1024) not found in reference data
# Warning: (week, id) pair (43, 1024) not found in reference data
# Warning: (week, id) pair (9, 1024) not found in reference data
# Warning: (week, id) pair (13, 1024) not found in reference data
# Warning: (week, id) pair (17, 1024) not found in reference data
# Warning: (week, id) pair (12, 1024) not found in reference data
# Warning: (week, id) pair (11, 1024) not found in reference data
# Warning: (week, id) pair (0, 1024) not found in reference data
# Warning: (week, id) pair (18, 1024) not found in reference data
# Warning: (week, id) pair (8, 1024) not found in reference data
# Warning: (week, id) pair (9, 1024) not found in reference data
# Warning: (week, id) pair (19, 1024) not found in reference data
# {-2: 694306, -1: 12417, 0: 925407, 1: 849164, 2: 701165}
# calculating proportions for haryana.csv
# {-2: 414, -1: 6, 0: 289, 1: 130, 2: 84}
# calculating proportions for maharashtra.csv
# {-2: 22595, -1: 640, 0: 25986, 1: 12195, 2: 17287}
# calculating proportions for bihar.csv
# {-2: 166, -1: 0, 0: 261, 1: 32, 2: 49}

# %% [markdown]
# ## Table of proportions of datapoints in citizen data which map to NA (missing) values in reference data
#
# ### total_obs
# total number of categorical observations for that dataframe `10 * len(dataframe)`
#
# ### proportion of {-2, -1, 0, 1, 2} <-> NA
# pct of `total_obs` which map one of {-2, -1, 0, 1, 2} to NA value

# %%
val_df.sort_values(by='total_obs', ascending=False).head()
# Out:
#         State Name  total_obs  proportion of -2 <-> NA  \
# 17          kerala    4872010                 0.142509
# 0       tamil_nadu     149920                 0.243757
# 8        karnataka     115510                 0.192330
# 11  madhya_pradesh      95530                 0.155700
# 19     maharashtra      89830                 0.251531
#
#     proportion of -1 <-> NA  proportion of 0 <-> NA  proportion of 1 <-> NA  \
# 17                 0.002549                0.189944                0.174294
# 0                  0.004509                0.204182                0.155523
# 8                  0.005939                0.204848                0.085594
# 11                 0.013001                0.309829                0.121585
# 19                 0.007125                0.289280                0.135756
#
#     proportion of 2 <-> NA
# 17                0.143917
# 0                 0.164788
# 8                 0.135763
# 11                0.105538
# 19                0.192441

# %% [markdown]
# ## Analysis
#
# - A large proportion of observations map to NA values; there is a lot of missing reference data
# - Many citizens actually observe the attribute (e.g. observation is 1 or 2) for NA reference data, which suggests that this reference data should exist
